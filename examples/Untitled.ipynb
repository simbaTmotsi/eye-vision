# %%
import ziso

# %%
test_image = ziso.read("test.jpg")

# %%
from ziso import view

# %%
view(test_image)

# %%
from ziso import read

# %%
bgr_test_image = ziso.read_bgr("test.jpg")

# %%
read.read_bgr()

# %%
view(bgr_test_image)

# %%
ziso.read_bgr("wrong_file.jpg")
# Out:
# Please check the file path, there seems to be an error

# %%
gray_test_image = ziso.read_gray("test.jpg")

# %%
view(gray_test_image)
