# %%
#import pytesseract
import cv2
from PIL import Image, ImageEnhance, ImageFilter

# %%
im = cv2.imread("icon.png")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(im)

# %%
mask_inv = cv2.bitwise_not(im)

# %%
plt.imshow(mask_inv)

# %%
ret,thresh5 = cv2.threshold(mask_inv,127,255,cv2.THRESH_TRUNC)

# %%
plt.imshow(thresh5)

# %%
cv2.imwrite('inv_icon.png',thresh3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-89aa7e629a41> in <module>()
# ----> 1 cv2.imwrite('inv_icon.png',thresh3)
#
# NameError: name 'thresh3' is not defined

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-13fdcd895f41> in <module>()
# ----> 1 pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"
#
# NameError: name 'pytesseract' is not defined

# %%
text = pytesseract.image_to_string(Image.open('temp2.jpg'))

# %%
print(text)

# %%
bgr_test_image = ziso.read_bgr("test.jpg")

# %%
read.read_bgr()
